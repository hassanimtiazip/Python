# %%
import pandas as pd    #importing pandas library

# %%
df=pd.read_csv("jsrt_metadata.csv",header=None)  # reading file data into df

# %%
df.head()  # display
# Out:
#               0    1     2   3       4       5       6          7  \
# 0  JPCLN001.png  5.0  15.0  53    Male  1634.0   692.0  malignant
# 1  JPCLN002.png  5.0  30.0  78  Female  1614.0  1090.0     benign
# 2  JPCLN003.png  5.0  30.0  63  Female  1303.0   447.0  malignant
# 3  JPCLN004.png  5.0  14.0  68  Female   606.0   836.0     benign
# 4  JPCLN005.png  5.0  35.0  73  Female  1438.0   692.0  malignant
#
#                     8                   9
# 0        l.upper lobe         lung cancer
# 1    l.upper lobe(S5)  pulmonary hematoma
# 2  l.upper lobe(S1+2)         lung cancer
# 3        r.upper lobe   Inflammatory mass
# 4    l.upper lobe(S3)         lung cancer

# %%
headers=["study_id","subtlety","size","age","gender","x","y","state","position","diagnosis"] #headers

# %%
df.columns=headers  #setting headers

# %%
df  #display all data
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       NaN   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       NaN   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       NaN   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       NaN   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       NaN   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# ...

# %%
# replace the missing value using numpy
import numpy as np

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety     93
# size         93
# age           0
# gender        0
# x            93
# y            93
# state         0
# position     93
# diagnosis    93
# dtype: int64

# %%
# for numerical replace with mean & for string replace with most frequent

#Replacing Subtlety Null Value with mean
m=df["subtlety"].astype('float').mean()
df['subtlety'].replace(np.nan,m,inplace=True) 
#---------------------------------------------------------------------------------

#Replacing Size Null Value with mean
m=df["size"].astype('float').mean()
df['size'].replace(np.nan,m,inplace=True)  
#---------------------------------------------------------------------------------

#Replacing x Null Value with mean
m=df["x"].astype('float').mean()
df['x'].replace(np.nan,m,inplace=True)
#---------------------------------------------------------------------------------

#Replacing y Null Value with mean
m=df["y"].astype('float').mean()
df['y'].replace(np.nan,m,inplace=True)
#---------------------------------------------------------------------------------

#Replacing Position Null Value with Most Frequent
m=df["position"].value_counts().idxmax()
df['position'].replace(np.nan,m,inplace=True)
#---------------------------------------------------------------------------------

#Replacing y Null Value  with Most Frequent
m=df["diagnosis"].value_counts().idxmax()
df['diagnosis'].replace(np.nan,m,inplace=True)
#---------------------------------------------------------------------------------

# %%
df.head(242)
# Out:
#          study_id  subtlety       size age  gender            x            y  \
# 0    JPCLN001.png   5.00000  15.000000  53    Male  1634.000000   692.000000
# 1    JPCLN002.png   5.00000  30.000000  78  Female  1614.000000  1090.000000
# 2    JPCLN003.png   5.00000  30.000000  63  Female  1303.000000   447.000000
# 3    JPCLN004.png   5.00000  14.000000  68  Female   606.000000   836.000000
# 4    JPCLN005.png   5.00000  35.000000  73  Female  1438.000000   692.000000
# ..            ...       ...        ...  ..     ...          ...          ...
# 237  JPCNN084.png   2.88961  17.246753  53  Female   937.324675   868.623377
# 238  JPCNN085.png   2.88961  17.246753  68  Female   937.324675   868.623377
# 239  JPCNN086.png   2.88961  17.246753  47    Male   937.324675   868.623377
# 240  JPCNN087.png   2.88961  17.246753  77  Female   937.324675   868.623377
# 241  JPCNN088.png   2.88961  17.246753  54    Male   937.324675   868.623377
#
# ...

# %%
df.isnull().sum() # all Null value sets
# Out:
# study_id     0
# subtlety     0
# size         0
# age          0
# gender       0
# x            0
# y            0
# state        0
# position     0
# diagnosis    0
# dtype: int64

# %%
# import Matplotlib Library for Graphs

import matplotlib as plt
from matplotlib import pyplot

# %% [markdown]
# # Task 1:

# %%
# task1:

plt.pyplot.title("Diagnosis Patient Histogram")
plt.pyplot.xlabel("X-axis")
plt.pyplot.ylabel("Y-axis")
plt.pyplot.hist(df['diagnosis'].value_counts(),color="yellow",ec="black")
# Out:
# (array([30.,  1.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([  1. ,  15.8,  30.6,  45.4,  60.2,  75. ,  89.8, 104.6, 119.4,
#         134.2, 149. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Task 2:

# %%
plt.pyplot.pie(df[['diagnosis', 'state']].value_counts(),shadow=True , autopct= '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x27848fc71c0>,
# ...
#  [Text(0.4160997880601955, 1.0182637017866543, ''),
#   Text(-1.0977763719436746, 0.0699073472689613, ''),
#   Text(-0.6476951466668902, -0.8890956062112532, ''),
#   Text(-0.1741504033155111, -1.0861268972937945, ''),
#   Text(0.1325903404163534, -1.091979762462783, ''),
#   Text(0.3372563642798493, -1.0470234690553684, ''),
#   Text(0.4799714817413008, -0.9897612725880217, ''),
#   Text(0.5780254272429179, -0.9358881372582102, ''),
#   Text(0.6700999667671853, -0.8723336715607264, ''),
#   Text(0.7450097309069345, -0.8092962997901184, ''),
#   Text(0.7949362176160618, -0.7603133629775749, ''),
#   Text(0.8325726606439009, -0.7189038633561069, ''),
#   Text(0.8680545649138726, -0.6756339780770263, ''),
#   Text(0.901290110046126, -0.6306156813250381, ''),
#   Text(0.9321932888084875, -0.5839654718392313, ''),
#   Text(0.9606841296867188, -0.5358040714366326, ''),
#   Text(0.9866889038354972, -0.4862561126072403, ''),
# ...

# %% [markdown]
# # Task 3:

# %%
plt.pyplot.pie(df[['diagnosis', 'gender']].value_counts(),startangle=90,shadow=True,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x27847c04f40>,
# ...
#  [Text(-0.8972615236143789, 0.6363346275672914, ''),
#   Text(-0.31722049422618886, -1.053266897819775, ''),
#   Text(0.8187064265143825, -0.7346562374226806, ''),
#   Text(1.0016492880490286, -0.4546412912955384, ''),
#   Text(1.0758653209711169, -0.22915892112618214, ''),
#   Text(1.0994439555151265, -0.03497125507116728, ''),
#   Text(1.0935777967360008, 0.11869120643937524, ''),
#   Text(1.072863663797945, 0.24282413163038516, ''),
#   Text(1.0426492986447584, 0.3505459171572155, ''),
#   Text(1.0073506178821314, 0.44186506158836336, ''),
#   Text(0.9707309574429595, 0.5173793659026956, ''),
#   Text(0.9284606723518127, 0.5898820050620464, ''),
#   Text(0.8890955455696534, 0.6476952299100253, ''),
#   Text(0.8550072148044573, 0.6920712843575616, ''),
#   Text(0.8187062889474065, 0.7346563907283227, ''),
#   Text(0.7802867078495221, 0.7753403469144081, ''),
#   Text(0.739847894036249, 0.8140178706208652, ''),
# ...
